# %%
def normalize_value(x, n_layers):
    max_val = 1 / n_layers
    min_val = 1 / (n_layers * 100)
    return (x - min_val) / (max_val - min_val)

# %%
print(normalize_value(0.014716,10))
# Out:
# 0.06422222222222222
